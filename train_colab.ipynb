# %% [markdown]
# # Install and import library

# %%
# !pip install torch_geometric
# !pip install torch-scatter
# !pip install openmesh
# !pip install torch-cluster
# !pip install torch-sparse

# %%
import os
import torch
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Colab Notebooks/3D-Reconstruction"
os.chdir(path)
print(os.getcwd())

# %%
print(torch.cuda.is_available())

# %%
import torch

if torch.cuda.is_available():
    gpu_count = torch.cuda.device_count()
    for i in range(gpu_count):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("No GPUs available")

# %%
# !python src/train/train.py --data_type=Synthetic --max_epoch=100 --flag=train --restore=1 --restore_time=2024-01-12-05-26-11 --last_epoch=5

# %%
from deepface import DeepFace
embedding_objs = DeepFace.represent(img_path = "1.jpg", enforce_detection=False, model_name="ArcFace")
print(embedding_objs)
# Out:
# [{'embedding': [-0.014583151787519455, 0.2038765847682953, -0.014309035614132881, -0.043968819081783295, -0.08862590044736862, 0.07539044320583344, 0.09688983112573624, 0.10912281274795532, 0.07582692056894302, 0.14262981712818146, 0.16362304985523224, 0.04863220453262329, -0.02969525009393692, 0.10456181317567825, -0.11984766274690628, 0.1500617414712906, 0.0344138965010643, 0.02036617323756218, 0.14695411920547485, -0.15951596200466156, -0.3345675468444824, -0.130557119846344, 0.10656429082155228, 0.1394420564174652, 0.0667305514216423, 0.0006382600404322147, -0.16896843910217285, -0.12790147960186005, 0.046152591705322266, -0.3382721245288849, 0.4032101631164551, -0.19341552257537842, -0.10041628032922745, 0.014524707570672035, 0.07516416162252426, 0.10265659540891647, -0.0662216767668724, 0.1646965742111206, -0.20796163380146027, -0.041457630693912506, 0.13814745843410492, -0.027558423578739166, -0.26187872886657715, -0.013273478485643864, 0.05294840410351753, -0.2226502746343612
# ...
